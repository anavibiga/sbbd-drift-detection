# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/processed/events_wide_minute.parquet')

# %%
df.shape
# Out:
# (36349, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36349 entries, 0 to 36348
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   match_id            36349 non-null  int64
#  1   period              36349 non-null  int64
#  2   minute_in_period    36349 non-null  int64
#  3   gol_casa            36349 non-null  float64
#  4   gol_fora            36349 non-null  float64
#  5   gol_open_play_casa  36349 non-null  float64
#  6   gol_open_play_fora  36349 non-null  float64
#  7   passe_casa          36349 non-null  float64
#  8   passe_fora          36349 non-null  float64
#  9   passe_certo_casa    36349 non-null  float64
#  10  passe_certo_fora    36349 non-null  float64
#  11  passe_errado_casa   36349 non-null  float64
#  12  passe_errado_fora   36349 non-null  float64
#  13  home_team           36349 non-null  object
#  14  away_team           36349 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# match_id              0
# period                0
# minute_in_period      0
# gol_casa              0
# gol_fora              0
# gol_open_play_casa    0
# gol_open_play_fora    0
# passe_casa            0
# passe_fora            0
# passe_certo_casa      0
# passe_certo_fora      0
# passe_errado_casa     0
# passe_errado_fora     0
# home_team             0
# away_team             0
# dtype: int64

# %%
df.head()
# Out:
#    match_id  period  minute_in_period  gol_casa  gol_fora  gol_open_play_casa  \
# 0    265839       1                 0       0.0       0.0                 0.0
# 1    265839       1                 1       0.0       0.0                 0.0
# 2    265839       1                 2       0.0       0.0                 0.0
# 3    265839       1                 3       0.0       0.0                 0.0
# 4    265839       1                 4       0.0       0.0                 0.0
#
#    gol_open_play_fora  passe_casa  passe_fora  passe_certo_casa  \
# 0                 0.0        13.0         1.0              12.0
# 1                 0.0         7.0        10.0               4.0
# 2                 0.0        13.0         2.0              11.0
# 3                 0.0        17.0         3.0              14.0
# 4                 0.0        15.0         5.0              12.0
#
#    passe_certo_fora  passe_errado_casa  passe_errado_fora  home_team away_team
# ...

# %%
# Checando se a quantidade de partidas está condizente
df['match_id'].nunique()
# Out:
# 380

# %%
# Checando se a quantidade de times está condizente
df['away_team'].nunique(), df['home_team'].nunique()
# Out:
# (20, 20)

# %%
# Checando se existem duplicatas
df.drop_duplicates().shape
# Out:
# (36349, 15)
